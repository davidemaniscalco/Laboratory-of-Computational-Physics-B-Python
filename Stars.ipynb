# %%
# -*- coding: utf-8 -*-
"""GAN.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1mcRDVVDZbfoO8A2CxlC7442URuej5BXB
"""

import tensorflow as tf
import numpy as np
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from IPython import display
from tensorflow.keras import layers, datasets
import os
import imageio
import shutil
import time
import PIL
from keras.initializers import RandomNormal

# Define a function to make data usable by a NN and another one to make the generated images in type to be plot
def preprocess(x, size, channels=1):    
    """ Define a function to make data usable by a NN """
    
    x = x.reshape(-1, size, size, channels) 
    x = np.float64(x)
    x = (x / 255 - 0.5) * 2
    x = np.clip(x, -1, 1)
    
    tx = tf.data.Dataset.from_tensor_slices(x)
    return tx

def deprocess(x, size, channels): 
    """ Define a function to make the generated images usable by imshow """
    
    x = (x / 2 + 1) * 255
    x = np.clip(x, 0, 255)
    x = np.uint8(x)
    if channels == 1:
      x = x.reshape(size, size)
    else:
      x = x.reshape(size, size, channels)
    return x


def make_labels(size):
    """ Define the labels to be used in the loss functions: 1's (real) or 0's (fake) """
    
    return tf.ones([size, 1]), tf.zeros([size, 1])

def make_trainable(model, trainable):
    """ To make trainable or not trainable the parameter of the a NN """
    
    for layer in model.layers:
        layer.trainable = trainable

class GAN():
    
    def __init__(self, name, data):
        
        self.name = name
        self.data = data
        self.val_frac = 0.01
        
        self.size = 32
        self.channels = 3
        self.batch_size = 128
        self.noise_dim = 100
        
        self.d_learning_rate = 0.001
        self.g_learning_rate = 0.0001
        self.d_beta1 = 0.9
        self.g_beta1 = 0.9
        self.leaky_alpha = 0.2
        
        self.epochs = 10
        self.model_complexity = 7
        self.smooth = 0.1
        self.samples_to_generate = 16
        self.training_time = 0
        self.seed = tf.random.normal([self.samples_to_generate, self.noise_dim])

        self.losses = {'gen': [], 'disc': []}
        
        self.networks = {"Generator": None, "Discriminator": None}

        # new working directory
        self.main_folder = '/content/GAN_' + str(self.name) + '/'
        if os.path.exists(self.main_folder):
          shutil.rmtree(self.main_folder)
          os.mkdir(self.main_folder)
        else:
          os.mkdir(self.main_folder)


    def set_training_parameters(self, epochs=50, batch_size=128, d_lr=0.001, g_lr=0.0001, d_beta=0.9, g_beta=0.9, alpha=0.2, smooth=0.1, vf=0.01,
                                size=32, ch=3, noise=100, smpls=16, mdl_cmplx=7):

        self.batch_size = batch_size
        self.d_learning_rate = d_lr
        self.g_learning_rate = g_lr
        self.d_beta1 = d_beta
        self.g_beta1 = g_beta
        self.leaky_alpha = alpha
        self.epochs = epochs
        self.smooth = smooth
        self.size = size
        self.channels = ch
        self.val_frac = vf
        self.noise_dim = noise
        self.samples_to_generate = smpls
        self.model_complexity = mdl_cmplx


    
    def build_generator(self, summary=False):

        s = self.size//8
        mc = self.model_complexity 

        model = tf.keras.Sequential()

        model.add(layers.Dense(s*s*2**(mc+3), use_bias=False, input_shape=(self.noise_dim,)))
        model.add(layers.Reshape(target_shape=(s, s, 2**(mc+3))))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(self.leaky_alpha))

        #prima mancante
        #model.add(layers.Conv2DTranspose(2**(mc+2), kernel_size=4, strides=2, padding='same', kernel_initializer=RandomNormal(stddev=0.2)))
        #model.add(layers.BatchNormalization())
        #model.add(layers.LeakyReLU(self.leaky_alpha))
        
        model.add(layers.Conv2DTranspose(2**(mc+1), kernel_size=4, strides=2, padding='same', kernel_initializer=RandomNormal(stddev=0.2)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(self.leaky_alpha))

        model.add(layers.Conv2DTranspose(2**mc, kernel_size=4, strides=2, padding='same', use_bias=False, kernel_initializer=RandomNormal(stddev=0.2)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(self.leaky_alpha))
        
        model.add(layers.Conv2DTranspose(self.channels, kernel_size=4, strides=2, padding='same', activation='tanh', kernel_initializer=RandomNormal(stddev=0.2)))      
        
        
        self.networks["Generator"] = model
        
        if summary: print(model.summary())
        
        return model
    
    
    def build_discriminator(self, summary=False):
        
        mc = self.model_complexity

        model = tf.keras.Sequential()

        model.add(layers.Conv2D(2**mc, kernel_size=4, strides=1, padding='same', input_shape=(self.size, self.size, self.channels)))
        model.add(layers.LeakyReLU(self.leaky_alpha))
        model.add(layers.Dropout(0.3))
        
        model.add(layers.Conv2D(2**(mc+1), kernel_size=4, strides=2, padding='same'))  
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(self.leaky_alpha))
        model.add(layers.Dropout(0.3))

        model.add(layers.Conv2D(2**(mc+2), kernel_size=4, strides=2, padding='same'))  
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(self.leaky_alpha))
        model.add(layers.Dropout(0.3))

        model.add(layers.Flatten())
        model.add(layers.Dense(1, activation='sigmoid'))


        self.networks["Discriminator"] = model
        
        if summary: print(model.summary())
        
        return model

    
    def Train(self, progress=False):

        test_size = int(self.val_frac*len(self.data))
        error_seed = self.make_latent_samples(test_size)
        
        x_train, x_test = train_test_split(self.data, test_size=self.val_frac)
        
        x_train_real = preprocess(x_train, self.size, self.channels)
        x_test_real  = preprocess(x_test, self.size, self.channels)

        x_train_real = x_train_real.batch(self.batch_size, drop_remainder=True)
     
        y_train_real, y_train_fake = make_labels(self.batch_size)
        y_eval_real,  y_eval_fake  = make_labels(test_size)
        
        # Generator
        generator = self.build_generator()

        # Discriminator
        discriminator = self.build_discriminator()
        discriminator.compile(optimizer=Adam(lr=self.d_learning_rate, beta_1=self.d_beta1), loss='binary_crossentropy')
        
        # GAN
        gan = tf.keras.Sequential([generator, discriminator])        
        gan.compile(optimizer=Adam(lr=self.g_learning_rate, beta_1=self.g_beta1), loss='binary_crossentropy')
    
        start = time.time()

        for epoch in tqdm(range(self.epochs)):

          # Shuffeling data each epoch
            x_train_real = x_train_real.shuffle(len(x_train), reshuffle_each_iteration=False) 
            x_test_real  = x_test_real.shuffle(len(x_test), reshuffle_each_iteration=False)

            for x_batch_real in x_train_real:
                
                # latent samples and the generated digit images
                latent_samples = self.make_latent_samples(n=self.batch_size)
                x_batch_fake = generator.predict_on_batch(latent_samples)
                
                # train the discriminator to detect real and fake images
                make_trainable(discriminator, True)
                discriminator.train_on_batch(x_batch_real, y_train_real * (1 - self.smooth))
                discriminator.train_on_batch(x_batch_fake, y_train_fake)
                
                # train the generator via GAN
                make_trainable(discriminator, False)
                gan.train_on_batch(latent_samples, y_train_real)
                

            # evaluate
            x_eval_real = list(x_test_real.as_numpy_iterator())
            x_eval_real = np.array(x_eval_real)[np.random.choice(len(x_test), test_size, replace=False)]

            #latent_samples = self.make_latent_samples(self.samples_to_generate)
            x_eval_fake_plot = generator.predict_on_batch(self.seed)
            x_eval_fake = generator.predict_on_batch(error_seed)
            
            d_loss  = discriminator.test_on_batch(x_eval_real, y_eval_real)
            d_loss += discriminator.test_on_batch(x_eval_fake, y_eval_fake) # total or average?
            g_loss  = gan.test_on_batch(error_seed, y_eval_real) 
                
            self.losses['disc'].append(d_loss)
            self.losses['gen'].append(g_loss)

            
            display.clear_output(wait=True)    
            if progress:
                print("Epoch:{:>3}/{},   Discriminator Loss:{:>7.4f},     Generator Loss:{:>7.4f}".format(epoch+1, self.epochs, d_loss, g_loss))
                self.show_progress(x_eval_fake_plot, epoch)

        self.training_time = time.time() - start
        print('\nTotal training time: ', self.training_time)
            

            
    
    def show_progress(self, generated_images, epoch):

        if os.path.exists(self.main_folder + 'progress_images/'):
          pass
        else: os.mkdir(self.main_folder + 'progress_images/')

        fig = plt.figure(figsize=(5,5))
        fig.suptitle('Epoch:{:4d}'.format(epoch+1), fontsize=15)
        for i in range(len(generated_images)):
            img = deprocess(generated_images[i], self.size, self.channels)
            plt.subplot(4, 4, i+1)
            if self.channels == 1:
              plt.imshow(img, cmap='gray')
            else:
              plt.imshow(img)
            plt.xticks([])
            plt.yticks([])
        plt.tight_layout()
        plt.subplots_adjust(top=0.9)
        plt.savefig(self.main_folder + 'progress_images/image_at_epoch_{:04d}.png'.format(epoch+1))
        plt.show()
        print()
        
        return
    
    
    def Plot_losses(self):
        losses = np.array([self.losses['disc'], self.losses['gen']])    
    
        fig, ax = plt.subplots()
        plt.plot(losses[0], label='Discriminator', color='blue')
        plt.plot(losses[1], label='Generator', color='red')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title("Training Losses")
        ax.set_ylim(bottom=0)
        plt.legend()
        plt.show()


    def Get_progress_GIF(self):
        
        im_dir = self.main_folder + '/progress_images/'
        images = []

        for file_name in sorted(os.listdir(im_dir)):
          if file_name.endswith('.png'):
            file_path = os.path.join(im_dir, file_name)
            images.append(imageio.imread(file_path))
        
        imageio.mimsave(self.main_folder + 'GAN.gif', images, fps=5)


    def Get_Model(self, key):
        return self.networks[key]
    
    def Save_parameters(self):
        with open(self.main_folder + 'parameters.txt', 'w') as file:
          file.write('Generative Adversarial Network: {}\n'.format(self.name))
          file.write('\n')
          file.write('Data shape: {}\n'.format(self.data.shape))
          file.write('Validation fraction: {}\n'.format(self.val_frac))
          file.write('Dimension of the latent data: {}\n'.format(self.noise_dim))

          file.write('\n' + '----- Discriminator -----\n')
          file.write('Learning rate of the discriminator: {}\n'.format(self.d_learning_rate))
          file.write('Beta parameter of the discriminator: {}\n'.format(self.d_beta1))
          file.write('Final loss of the discriminator: {}\n'.format(self.losses['disc'][-1]))
          self.networks['Discriminator'].summary(print_fn=lambda x: file.write(x + '\n'))

          file.write('\n' + '----- Generator -----\n')
          file.write('Learning rate of the generator: {}\n'.format(self.g_learning_rate))
          file.write('Beta parameter of the generator: {}\n'.format(self.g_beta1))
          file.write('Final loss of the generator: {}\n'.format(self.losses['gen'][-1]))
          self.networks['Generator'].summary(print_fn=lambda x: file.write(x + '\n'))

          file.write('\n' + '----- Training parameters -----\n')
          file.write('Number of epochs: {}\n'.format(self.epochs))
          file.write('Smooth on the discriminator: {}\n'.format(self.smooth))
          file.write('Total training time: {}\n'.format(self.training_time))
          file.write('Model complexity: {}\n'.format(self.model_complexity))
    
    def Save_model(self, key, path):   
        target = path + "/" + self.name + '.h5'        
        self.networks[key].save(target)
        print(key + " successfully saved")
        return
    
    def Restore_model(self, key, path):
        self.networks[key] = tf.keras.models.load_model(path)
        print(key + " successfully restored")
        return 
    
    def make_latent_samples(self, n=1):
        noise = tf.random.normal([n, self.noise_dim])
        return noise

# %%
# IMPORT DATA
#(X_train, _), (X_test, _) = datasets.mnist.load_data()
#images = np.concatenate([X_train, X_test])
#images = np.array([images[i].reshape((32,32)) for i in range(len(images))])

from google.colab import drive
drive.mount('/content/drive')

# To unpack data, in case
#!tar -xvf drive/My\ Drive/Colab\ Notebooks/20ksquares.tar -C /content/
#!tar -xvf drive/My\ Drive/Colab\ Notebooks/20kcircles.tar -C /content/
#!tar -xvf drive/My\ Drive/Colab\ Notebooks/20ktriangles.tar -C /content/
#!tar -xvf drive/My\ Drive/Colab\ Notebooks/20kstars.tar -C /content/
# !tar -xvf drive/My\ Drive/20kredstars.tar -C /content/
#!tar -xvf drive/My\ Drive/Colab\ Notebooks/20kshapes.tar -C /content/
#!tar -xvf drive/My\ Drive/Colab\ Notebooks/20k4shapes.tar -C /content/
#!tar -xvf drive/My\ Drive/Colab\ Notebooks/celeba64.tar -C /content/

images_path = 'pics_star/'
SIZE = 48

image_names = os.listdir(images_path)
images = np.array([imageio.imread(images_path+im) for im in image_names])
print("Data dimension: ", images.shape)

# Scaling images 
images = np.array([np.asarray(PIL.Image.fromarray(images[i]).resize((SIZE, SIZE))) for i in range(len(images)-1)])

# Conversion from RGBA to grayscale
#images = np.array([np.mean(images[i],axis=2) for i in range(len(images))])

# Conversion from RGBA to RGB
images = np.array([np.asarray(PIL.Image.fromarray(images[i]).convert("RGB")) for i in range(len(images))])

print("New data dimension: ", images.shape)
plt.imshow(images[np.random.randint(len(images))])

# %%
DCGAN = GAN(name="Images", data=images)

DCGAN.set_training_parameters(epochs=200, batch_size=128, d_lr=0.001, g_lr=0.0001, d_beta=0.5, g_beta=0.5, alpha=0.2, smooth=0.1, vf=0.01,
                                size=48, ch=3, noise=100, smpls=16, mdl_cmplx=4)

DCGAN.build_generator(summary=True)
DCGAN.build_discriminator(summary=True)

DCGAN.Train(progress=True)

DCGAN.Plot_losses()
DCGAN.Save_parameters()

DCGAN.Get_progress_GIF()
# Out:
# Epoch:200/200,   Discriminator Loss: 1.2401,     Generator Loss: 3.5543
# 100%|██████████| 200/200 [45:35<00:00, 13.68s/it]
# Total training time:  2735.3944590091705

# %%
# !zip -r /content/GAN_Images.zip /content/GAN_Images
# Out:
# updating: content/GAN_Images/ (stored 0%)
# updating: content/GAN_Images/parameters.txt (deflated 82%)
# updating: content/GAN_Images/GAN.gif (deflated 43%)
# updating: content/GAN_Images/progress_images/ (stored 0%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0144.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0135.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0141.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0004.png (deflated 0%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0020.png (deflated 10%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0174.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0012.png (deflated 6%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0164.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0086.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0102.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0071.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0080.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0048.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0169.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0027.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0146.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0021.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0047.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0110.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0167.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0068.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0134.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0113.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0119.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0179.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0112.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0095.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0049.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0023.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0159.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0054.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0043.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0117.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0079.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0077.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0089.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0103.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0171.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0153.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0175.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0082.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0056.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0003.png (deflated 0%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0092.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0078.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0118.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0084.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0096.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0005.png (deflated 0%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0132.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0037.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0157.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0009.png (deflated 1%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0104.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0154.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0076.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0122.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0193.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0050.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0108.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0192.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0025.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0120.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0184.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0026.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0156.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0155.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0126.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0185.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0085.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0123.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0066.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0019.png (deflated 10%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0090.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0125.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0188.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0075.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0111.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0172.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0165.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0152.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0015.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0105.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0181.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0028.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0010.png (deflated 2%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0148.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0115.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0018.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0007.png (deflated 0%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0087.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0032.png (deflated 10%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0149.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0138.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0040.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0070.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0051.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0131.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0045.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0073.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0052.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0011.png (deflated 4%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0029.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0061.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0030.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0129.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0189.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0081.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0101.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0133.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0163.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0199.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0006.png (deflated 0%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0173.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0058.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0069.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0036.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0176.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0017.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0041.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0114.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0091.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0038.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0106.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0130.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0065.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0072.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0178.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0128.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0060.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0196.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0147.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0039.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0180.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0093.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0100.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0194.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0088.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0046.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0013.png (deflated 6%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0014.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0170.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0139.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0168.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0198.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0158.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0116.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0186.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0053.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0142.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0063.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0151.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0035.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0044.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0083.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0001.png (deflated 0%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0190.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0121.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0177.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0024.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0107.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0162.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0197.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0008.png (deflated 0%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0064.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0055.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0067.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0143.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0033.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0195.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0182.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0183.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0002.png (deflated 0%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0074.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0062.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0161.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0124.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0191.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0160.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0200.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0099.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0094.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0098.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0042.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0150.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0166.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0034.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0136.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0187.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0059.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0022.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0057.png (deflated 7%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0140.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0016.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0031.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0109.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0127.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0145.png (deflated 8%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0097.png (deflated 9%)
# updating: content/GAN_Images/progress_images/image_at_epoch_0137.png (deflated 8%)

# %%
DCGAN.Save_parameters()

# %%
image.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1c83375060d0> in <module>()
# ----> 1 image.shape
#
# NameError: name 'image' is not defined

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
